# %% [markdown]
# #   Spotify and Youtube data analysis![image.png](attachment:image.png)

# %% [markdown]
# ##  Description of dataset
# This dataset is downloaded from kaggle.This dataset contain 23 columns and 20718 rows and this dataset contain attributes such as like, views and title etc. I am trying to do analysis on this dataset based on views and likes.
# I am  going to analyze the data deeply and try to get some useful insights like top artists ,trending music etc.
# I am going to use pandas and numpy library for analysis. Pandas is a most popular library in analysis and numpy is mostly used for working in numerical values. i will also import seaborn and matplotlib for visualization graph.
#
#
# It includes 27 variables  collected from spotify. These variables are briefly described :
#
# 1. Track: name of the song, as visible on the Spotify platform.
# 2. Artist: name of the artist.
# 3. Url_spotify: the Url of the artist.
# 4. Album: the album in wich the song is contained on Spotify.
# 5. Album_type: indicates if the song is relesead on Spotify as a single or contained in an album.
# 6. Uri: a spotify link used to find the song through the API.
# 7. Danceability: describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# 8. Energy: is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
# 9. Key: the key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
# 10. Loudness: the overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
# 11. Speechiness: detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
# 12. Acousticness: a confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# 13. Instrumentalness: predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
# 14. Liveness: detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
# 15. Valence: a measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
# 16. Tempo: the overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
# 17. Duration_ms: the duration of the track in milliseconds.
# 18. Stream: number of streams of the song on Spotify.
# 19. Url_youtube: url of the video linked to the song on Youtube, if it have any.
# 20. Title: title of the videoclip on youtube.
# 21. Channel: name of the channel that have published the video.
# 22. Views: number of views.
# 23. Likes: number of likes.
# 24. Comments: number of comments.
# 25. Description: description of the video on Youtube.
# 26. Licensed: Indicates whether the video represents licensed content, which means that the content was uploaded to a channel linked to a YouTube content partner and then claimed by that partner.
# 27. official_video: boolean value that indicates if the video found is the official video of the song.

# %% [markdown]
# ## Goal of the project
# In this projet, We're going to explore these Songs in order to understand and find insights between Spotify and YouTube songs. We're going to see what was the characteristics of this songs and analysis on top songs on spotify.

# %% [markdown]
# ## Tools used
#     1. pandas for data manipulation
#     2. numpy is mostly used for working in numerical values
#     3. Seaborn and matplotlib  for visualization graph.

# %%
# !pip install jovian opendatasets --upgrade --quiet

# %% [markdown]
# Let's begin by downloading the data, and listing the files within the dataset.

# %%
dataset_url = 'https://www.kaggle.com/datasets/salvatorerastelli/spotify-and-youtube'

# %%
import opendatasets as od
od.download('https://www.kaggle.com/datasets/salvatorerastelli/spotify-and-youtube' )
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: artigupta18
# Your Kaggle Key: ········
# ...
# 100%|██████████| 8.95M/8.95M [00:02<00:00, 4.28MB/s]

# %% [markdown]
# The dataset has been downloaded and extracted.

# %%
data_dir = './spotify-and-youtube'

# %%
import os
os.listdir('./spotify-and-youtube')
# Out:
# ['Spotify_Youtube.csv']

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
project_name = "spotify-and-youtube-course-project-starter"

# %%
# !pip install jovian --upgrade -q

# %%
import jovian

# %%
jovian.commit(project="spotify-and-youtube-course-project-starter")
# Out:
# [jovian] Updating notebook "artigupta180603/spotify-and-youtube-course-project-starter" on https://jovian.com
# [jovian] Committed successfully! https://jovian.com/artigupta180603/spotify-and-youtube-course-project-starter
# 'https://jovian.com/artigupta180603/spotify-and-youtube-course-project-starter'

# %%
import pandas as pd
import numpy as np

# %%
spotube_df=pd.read_csv('./spotify-and-youtube/Spotify_Youtube.csv')

# %%
spotube_df.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
spotube_df.head(10)
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 5           5  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6           6  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 7           7  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 8           8  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 9           9  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                                Track  \
# 0                                     Feel Good Inc.
# ...

# %%
spotube_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %%
spotube_df.drop(["Description",'Unnamed: 0',"Url_spotify"],axis=1,inplace=True)
spotube_df.drop(["Danceability"],axis=1,inplace=True)
spotube_df.drop(["Uri"],axis=1,inplace=True)
spotube_df
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20713  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20714  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20715  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20716  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20717  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Energy   Key  \
# 0                                         Demon Days      album   0.705   6.0
# ...

# %% [markdown]
# After loading the data and getting a basic view of the data table, a few adjustments and basic calculations can be performed. There are a couple of columns that will be irrelevant for performing EDA. These columns are removed from the data frame.

# %%
spotube_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# After removing a few columns, the duplicated function is run to see if there are any duplicates in the data frame.

# %%
spotube_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20718 non-null  object
#  1   Track             20718 non-null  object
#  2   Album             20718 non-null  object
#  3   Album_type        20718 non-null  object
#  4   Energy            20716 non-null  float64
#  5   Key               20716 non-null  float64
#  6   Loudness          20716 non-null  float64
#  7   Speechiness       20716 non-null  float64
#  8   Acousticness      20716 non-null  float64
#  9   Instrumentalness  20716 non-null  float64
#  10  Liveness          20716 non-null  float64
#  11  Valence           20716 non-null  float64
#  12  Tempo             20716 non-null  float64
#  13  Duration_ms       20716 non-null  float64
#  14  Url_youtube       20248 non-null  object
#  15  Title             20248 non-null  object
# ...

# %%
spotube_df.describe()
# Out:
#              Energy           Key      Loudness   Speechiness  Acousticness  \
# count  20716.000000  20716.000000  20716.000000  20716.000000  20716.000000
# mean       0.635250      5.300348     -7.671680      0.096456      0.291535
# std        0.214147      3.576449      4.632749      0.111960      0.286299
# min        0.000020      0.000000    -46.251000      0.000000      0.000001
# 25%        0.507000      2.000000     -8.858000      0.035700      0.045200
# 50%        0.666000      5.000000     -6.536000      0.050500      0.193000
# 75%        0.798000      8.000000     -4.931000      0.103000      0.477250
# max        1.000000     11.000000      0.920000      0.964000      0.996000
#
#        Instrumentalness      Liveness       Valence         Tempo  \
# count      20716.000000  20716.000000  20716.000000  20716.000000
# mean           0.055962      0.193521      0.529853    120.638340
# std            0.193262      0.168531      0.245441     29.579018
# ...

# %%
spotube_df.shape
# Out:
# (20718, 23)

# %%
spotube_df['Artist'].value_counts()
# Out:
# Gorillaz                  10
# Die drei !!!              10
# Hollywood Undead          10
# Empire of the Sun         10
# White Noise for Babies    10
#                           ..
# NewJeans                   6
# Alfonso Herrera            6
# Jimin                      3
# Stars Music Chile          1
# Bootie Brown               1
# Name: Artist, Length: 2079, dtype: int64

# %%
spotube_df['Album_type'].value_counts()
# Out:
# album          14926
# single          5004
# compilation      788
# Name: Album_type, dtype: int64

# %% [markdown]
# A basic form of exploratory data analysis is using value counts to see how the data is distributed. The value counts function is used to see the value counts for artists and album type.

# %%
spotube_df.sort_values('Energy',ascending=False).head(10)
# Out:
#                    Artist                            Track  \
# 20585  Rain Fruits Sounds     Rain and Thunderstorm, Pt. 7
# 20587  Rain Fruits Sounds    Rain and Thunderstorm, Pt. 33
# 20582  Rain Fruits Sounds     Rain and Thunderstorm, Pt. 4
# 20581  Rain Fruits Sounds     Rain and Thunderstorm, Pt. 3
# 20652      Sleepy Penguin            Gentle Piano Melodies
# 20586  Rain Fruits Sounds     Rain and Thunderstorm, Pt. 6
# 20588  Rain Fruits Sounds    Rain and Thunderstorm, Pt. 37
# 20653      Sleepy Penguin        Soothing Baby White Nosie
# 10292         The Prodigy                    Voodoo People
# 20646      Sleepy Penguin  Relaxing Baby White Noise Piano
#
#                                     Album Album_type  Energy  Key  Loudness  \
# 20585               Rain and Thunderstorm      album   1.000  9.0   -25.071
# 20587               Rain and Thunderstorm      album   1.000  8.0   -25.175
# 20582               Rain and Thunderstorm      album   1.000  7.0   -25.603
# ...

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "artigupta180603/spotify-and-youtube-course-project-starter" on https://jovian.com
# [jovian] Committed successfully! https://jovian.com/artigupta180603/spotify-and-youtube-course-project-starter
# 'https://jovian.com/artigupta180603/spotify-and-youtube-course-project-starter'

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# #### To plot the barplot by showing the top 10 artist by views.

# %%
artist_views = spotube_df.groupby('Artist', as_index = False).sum().sort_values(by = 'Views', ascending = False)
fig, ax = plt.subplots(figsize = (8,10))
sns.barplot(x = artist_views['Views'][:10], y = artist_views['Artist'][:10])
plt.xticks(rotation = 90)
ax.set_title('Top 10 Artists by Views')
ax.set_xlabel('Total Views (Billions)')
# Out:
# Text(0.5, 0, 'Total Views (Billions)')

# %% [markdown]
# This barplot shows that the Ed Sheeran and CoComelon are most popular artist as these two have more no of likes than other artist.

# %% [markdown]
# #### To plot the heatmap for the correlation of variables.

# %%
fig,ax=plt.subplots(figsize = (13, 8))
sns.heatmap(data = spotube_df.corr().round(2),annot = True)
plt.title("Correlation between variables")
plt.ylabel("Column names in ordinate axis")
plt.xlabel("Column names on x axis")
plt.show()

# %%
spotube_df.corr()
# Out:
#                     Energy       Key  Loudness  Speechiness  Acousticness  \
# Energy            1.000000  0.030160  0.744845     0.065319     -0.658304
# Key               0.030160  1.000000  0.025266     0.019778     -0.030818
# Loudness          0.744845  0.025266  1.000000     0.033699     -0.547680
# Speechiness       0.065319  0.019778  0.033699     1.000000     -0.077598
# Acousticness     -0.658304 -0.030818 -0.547680    -0.077598      1.000000
# Instrumentalness -0.310058  0.000747 -0.545406    -0.109895      0.274379
# Liveness          0.173717 -0.011008  0.087062     0.085463     -0.040922
# Valence           0.389158  0.042559  0.311578     0.059204     -0.200816
# Tempo             0.157383  0.001855  0.144766     0.037553     -0.129367
# Duration_ms       0.022660  0.003186  0.012063    -0.051248     -0.028834
# Views             0.067575  0.007767  0.119244    -0.013240     -0.071240
# Likes             0.062824  0.006751  0.124887     0.007495     -0.078591
# ...

# %% [markdown]
# From the figure above, we can conclude the following:
#
# There is a positive correlation between Energy and the following variables: Key, Loudness , Speechiness,Valence, Tempo,Duration_ms, Views, Likes, Comments and Stream.
#
# Heat Maps are graphical representations of data that utilize color-coded systems. The correlation heat map only considers variables with numerical values, so some variables will be excluded, such as 'Artist' and 'Album'.

# %% [markdown]
# #### To plot the bar chart to show the top 10 artist which has more likes.

# %%
spotube_df_grouped=spotube_df.groupby("Artist")["Likes"].sum().reset_index()
spotube_df_sorted=spotube_df_grouped.sort_values(by="Likes",ascending=False)
sns.barplot(x='Likes',y='Artist',data=spotube_df_sorted.head(10))
plt.xlabel("number of likes")
plt.ylabel("Artist")
plt.title("Top 10 Artist")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# This barplot shows that the BTS and BLACKPINK are most popular artistin as these two have more no of likes than other artist

# %% [markdown]
# #### To plot the countplot to find which album_type has higher no of count.

# %%
sns.countplot(x ='Album_type',data = spotube_df,hue=spotube_df['official_video'])
plt.title("Total number of official and unofficial video")
plt.show()

# %% [markdown]
#  This countplot shows that the number of official and unofficial video in album, single and compilation and number of album is more than the single and compilation in album_type.

# %% [markdown]
# #### To plot the line plot to find the most liked song.

# %%
spotube_df_grouped=spotube_df.groupby("Track")["Likes"].sum().reset_index()
spotube_df_sorted=spotube_df_grouped.sort_values(by="Likes",ascending=False)
sns.lineplot(x='Likes',y='Track',data=spotube_df_sorted.head(10))
plt.title("Top 10 most like song")
plt.xlabel("number of likes")
plt.ylabel("Track")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# In this lineplot ,groupby function is used to grouping the data of track and this shows that the despacito song has more number of likes.

# %% [markdown]
# Let us save and upload our work to Jovian before continuing

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "artigupta180603/spotify-and-youtube-course-project-starter" on https://jovian.com
# [jovian] Committed successfully! https://jovian.com/artigupta180603/spotify-and-youtube-course-project-starter
# 'https://jovian.com/artigupta180603/spotify-and-youtube-course-project-starter'

# %% [markdown]
# #### Q1: Create a data frame that counts the Album_type of each Artist.

# %%
total_albums_df=spotube_df.groupby('Artist')[['Album_type']].count()

# %%
total_albums_df
# Out:
#                 Album_type
# Artist
# $NOT                    10
# $uicideboy$             10
# (G)I-DLE                10
# *NSYNC                  10
# 070 Shake               10
# ...                    ...
# will.i.am               10
# Ángela Aguilar          10
# Ñejo                    10
# Ñengo Flow              10
# Øneheart                10
#
# [2079 rows x 1 columns]

# %% [markdown]
# This shows that the each artist and their total number of Album_type.

# %% [markdown]
# #### Q2: Show that the number of albums,single,compilation in Album_type with the help of pie chart.

# %%
spotube_df["Album_type"].value_counts().plot(kind="pie")
plt.title("count the total value of each types of Album")
plt.show()

# %% [markdown]
#  This pie chart shows that the album is higher than the single and compilation in Album_type.

# %% [markdown]
# #### Q3: Based on the views ,What are the top 10 songs on youtube?

# %%
song_views = spotube_df.groupby('Track', as_index = False).sum().sort_values(by = 'Views', ascending = False)
fig, ax = plt.subplots(figsize = (8,10))
sns.barplot(x = song_views['Views'][:10], y = song_views['Track'][:10])
plt.xticks(rotation = 90)
ax.set_title('Top 10 Songs by Views')
ax.set_xlabel('Total Views (Billions)')
# Out:
# Text(0.5, 0, 'Total Views (Billions)')

# %% [markdown]
# This barplot shows that the 10 latest songs on youtube in which Despescito and See you again are most popular songs as these two have more no of views than other songs.

# %% [markdown]
# #### Q4: Sorting the Views data in spotube data frame.

# %%
highest_views_df=spotube_df.sort_values('Views',ascending=False).head(10)

# %%
highest_views_df
# Out:
#              Artist                               Track  \
# 1147     Luis Fonsi                           Despacito
# 365    Daddy Yankee                           Despacito
# 12452    Ed Sheeran                        Shape of You
# 14580  Charlie Puth  See You Again (feat. Charlie Puth)
# 12469   Wiz Khalifa  See You Again (feat. Charlie Puth)
# 20303     CoComelon                   Wheels on the Bus
# 10686   Mark Ronson      Uptown Funk (feat. Bruno Mars)
# 8937            PSY               Gangnam Style (강남스타일)
# 9569       Maroon 5                               Sugar
# 13032    Katy Perry                                Roar
#
#                                     Album Album_type  Energy   Key  Loudness  \
# 1147                                 VIDA      album   0.797   2.0    -4.787
# 365                                  VIDA      album   0.797   2.0    -4.787
# 12452                          ÷ (Deluxe)      album   0.652   1.0    -3.183
# ...

# %% [markdown]
# #### Q5:Find the top 10 spotified channel which have more number of views?

# %%
df_channels = spotube_df.groupby("Channel")["Views"].sum().reset_index()
df_sort_channels = df_channels.sort_values("Views", ascending=False).head(10)
sns.set_style("whitegrid")
sns.barplot(x="Views", y="Channel", data=df_sort_channels, color='b')
sns.despine(left=True)
plt.title('Top Spotify Channels by Views')
plt.xlabel('Views')
plt.ylabel('Channel')
plt.show()

# %% [markdown]
# This bar graph shows the top 10 spotify channel in which T-series is the number one channel which has more number of views.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "artigupta180603/spotify-and-youtube-course-project-starter" on https://jovian.com
# [jovian] Committed successfully! https://jovian.com/artigupta180603/spotify-and-youtube-course-project-starter
# 'https://jovian.com/artigupta180603/spotify-and-youtube-course-project-starter'

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "artigupta180603/spotify-and-youtube-course-project-starter" on https://jovian.com
# [jovian] Committed successfully! https://jovian.com/artigupta180603/spotify-and-youtube-course-project-starter
# 'https://jovian.com/artigupta180603/spotify-and-youtube-course-project-starter'

# %% [markdown]
# ## References and Future Work
#
# This session was a short exploratory data analysis of Spotify and YouTube data. From the data, bar charts were created to see artists and songs, as well as the top songs for a specific artist. With the 2023 season coming soon, all these calculations can be changed quickly by alternating the seasons parameter.
# The graphs could be made clearer by setting the colours to the respective team colours.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "artigupta180603/spotify-and-youtube-course-project-starter" on https://jovian.com
# [jovian] Committed successfully! https://jovian.com/artigupta180603/spotify-and-youtube-course-project-starter
# 'https://jovian.com/artigupta180603/spotify-and-youtube-course-project-starter'
